# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Load Dataset

# %%
sleep_df = pd.read_csv(
    "/kaggle/input/fitbit/mturkfitbit_export_4.12.16-5.12.16/Fitabase Data 4.12.16-5.12.16/sleepDay_merged.csv",
    parse_dates=["SleepDay"],
    date_format="%m/%d/%Y %I:%M:%S %p"
)


steps_df = pd.read_csv(
    "/kaggle/input/fitbit/mturkfitbit_export_4.12.16-5.12.16/Fitabase Data 4.12.16-5.12.16/hourlySteps_merged.csv",
    parse_dates=["ActivityHour"],
     date_format="%m/%d/%Y %I:%M:%S %p"
)

cal_df = pd.read_csv(
    "/kaggle/input/fitbit/mturkfitbit_export_4.12.16-5.12.16/Fitabase Data 4.12.16-5.12.16/hourlyCalories_merged.csv",
    parse_dates=["ActivityHour"],
    date_format="%m/%d/%Y %I:%M:%S %p"
)

hr_df = pd.read_csv(
    "/kaggle/input/fitbit/mturkfitbit_export_4.12.16-5.12.16/Fitabase Data 4.12.16-5.12.16/heartrate_seconds_merged.csv",
    parse_dates=["Time"],
    date_format="%m/%d/%Y %I:%M:%S %p"
)

# %%
sleep_df = sleep_df.sort_values(["Id", "SleepDay"])
steps_df = steps_df.sort_values(["Id", "ActivityHour"])
cal_df = cal_df.sort_values(["Id", "ActivityHour"])
hr_df = hr_df.sort_values(["Id", "Time"])

# Ensure datetime (extra safety)
hr_df["Time"] = pd.to_datetime(hr_df["Time"])

# ================================
# 3. RESAMPLE HEART RATE → HOURLY
# ================================

hr_hourly = (
    hr_df
    .set_index("Time")
    .groupby("Id")["Value"]
    .resample("h")        # ✅ lowercase h (future-proof)
    .mean()
    .reset_index()
    .rename(columns={"Value": "heart_rate"})
)

# %%
df = steps_df.merge(cal_df, on=["Id", "ActivityHour"])
df = df.merge(hr_hourly, left_on=["Id", "ActivityHour"], right_on=["Id", "Time"])
df.drop(columns=["Time"], inplace=True)

# %%
sleep_df["SleepDate"] = sleep_df["SleepDay"].dt.date
df["SleepDate"] = df["ActivityHour"].dt.date

df = df.merge(
    sleep_df[["Id", "SleepDate", "TotalMinutesAsleep"]],
    on=["Id", "SleepDate"],
    how="inner"
)

# %%
rhr = (
    df.groupby("Id")["heart_rate"]
    .quantile(0.25)
    .reset_index()
    .rename(columns={"heart_rate": "resting_hr"})
)

df = df.merge(rhr, on="Id")
df["stress"] = df["heart_rate"] - df["resting_hr"]
df = df.dropna()

# %%
df["sleep_score"] = np.clip((df["TotalMinutesAsleep"] / 480) * 100, 0, 100)
df["rhr_score"] = np.clip(100 - (df["resting_hr"] - 60) * 2, 0, 100)
df["hrv_score"] = np.clip(100 - abs(df["heart_rate"] - df["resting_hr"]), 0, 100)
df["recovery_score"] = np.clip(100 - df["stress"] * 5, 0, 100)

df["readiness_score"] = (
    0.30 * df["sleep_score"] +
    0.25 * df["recovery_score"] +
    0.20 * df["hrv_score"] +
    0.15 * df["rhr_score"]
)

# %%
FEATURES = ["StepTotal", "Calories", "heart_rate", "stress"]
TARGETS = ["sleep_score", "hrv_score", "rhr_score", "recovery_score", "readiness_score"]

scaler = MinMaxScaler()
df[FEATURES] = scaler.fit_transform(df[FEATURES])

# %%
SEQ_LEN = 6
X, y = [], []

for user in df["Id"].unique():
    user_df = df[df["Id"] == user].sort_values("ActivityHour")

    for i in range(len(user_df) - SEQ_LEN):
        X.append(user_df[FEATURES].iloc[i:i+SEQ_LEN].values)
        y.append(user_df[TARGETS].iloc[i+SEQ_LEN].values)

X = np.array(X)
y = np.array(y)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# =========================
# MODEL
# =========================

input_layer = Input(shape=(SEQ_LEN, len(FEATURES)))

shared = LSTM(64, return_sequences=True, name="encoder_lstm_1")(input_layer)
shared = LSTM(32, name="encoder_lstm_2")(shared)
shared = Dropout(0.3)(shared)

sleep_out = Dense(1, name="sleep")(shared)
hrv_out = Dense(1, name="hrv")(shared)
rhr_out = Dense(1, name="rhr")(shared)
recovery_out = Dense(1, name="recovery")(shared)
readiness_out = Dense(1, name="readiness")(shared)

fitbit_model = Model(
    input_layer,
    [sleep_out, hrv_out, rhr_out, recovery_out, readiness_out]
)

# =========================
# COMPILE (BENAR)
# =========================

fitbit_model.compile(
    optimizer=Adam(0.001),
    loss={
        "sleep": "mse",
        "hrv": "mse",
        "rhr": "mse",
        "recovery": "mse",
        "readiness": "mse"
    },
    metrics={
        "sleep": "mae",
        "hrv": "mae",
        "rhr": "mae",
        "recovery": "mae",
        "readiness": "mae"
    }
)

# =========================
# FIT
# =========================

fitbit_model.fit(
    X,
    {
        "sleep": y[:, 0],
        "hrv": y[:, 1],
        "rhr": y[:, 2],
        "recovery": y[:, 3],
        "readiness": y[:, 4],
    },
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - hrv_loss: 7839.0410 - hrv_mae: 87.8925 - loss: 33488.1289 - readiness_loss: 5158.2046 - readiness_mae: 70.5637 - recovery_loss: 4599.5542 - recovery_mae: 56.8026 - rhr_loss: 8423.0957 - rhr_mae: 91.3129 - sleep_loss: 7468.2285 - sleep_mae: 84.4968 - val_hrv_loss: 7120.9619 - val_hrv_mae: 84.1197 - val_loss: 29441.7266 - val_readiness_loss: 4407.6519 - val_readiness_mae: 65.6329 - val_recovery_loss: 3844.1470 - val_recovery_mae: 53.2731 - val_rhr_loss: 7112.4443 - val_rhr_mae: 84.0574 - val_sleep_loss: 6739.0610 - val_sleep_mae: 80.3178
# Epoch 2/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 6915.2310 - hrv_mae: 82.4043 - loss: 29062.6973 - readiness_loss: 4343.0776 - readiness_mae: 64.4936 - recovery_loss: 3917.8784 - recovery_mae: 52.5669 - rhr_loss: 7423.3896 - rhr_mae: 85.6636 - sleep_loss: 6463.1226 - sleep_mae: 78.3181 - val_hrv_loss: 6538.8735 - val_hrv_mae: 80.5740 - val_loss: 26928.5566 - val_readiness_loss: 3960.9189 - val_readiness_mae: 62.1130 - val_recovery_loss: 3518.0042 - val_recovery_mae: 51.1031 - val_rhr_loss: 6525.8970 - val_rhr_mae: 80.4990 - val_sleep_loss: 6181.9067 - val_sleep_mae: 76.7782
# Epoch 3/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 6407.5425 - hrv_mae: 79.3313 - loss: 26769.4102 - readiness_loss: 3939.2104 - readiness_mae: 61.3601 - recovery_loss: 3646.5237 - recovery_mae: 51.1202 - rhr_loss: 6826.7783 - rhr_mae: 82.1051 - sleep_loss: 5949.3574 - sleep_mae: 74.9555 - val_hrv_loss: 6027.3164 - val_hrv_mae: 77.3234 - val_loss: 24738.1777 - val_readiness_loss: 3574.8538 - val_readiness_mae: 58.9008 - val_recovery_loss: 3241.8403 - val_recovery_mae: 49.2044 - val_rhr_loss: 6010.7896 - val_rhr_mae: 77.2392 - val_sleep_loss: 5693.6274 - val_sleep_mae: 73.6096
# Epoch 4/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 5884.2925 - hrv_mae: 75.8933 - loss: 24545.7168 - readiness_loss: 3542.2498 - readiness_mae: 57.9304 - recovery_loss: 3349.9514 - recovery_mae: 49.3498 - rhr_loss: 6336.0361 - rhr_mae: 79.0538 - sleep_loss: 5433.1865 - sleep_mae: 71.3566 - val_hrv_loss: 5557.0098 - val_hrv_mae: 74.2089 - val_loss: 22744.3691 - val_readiness_loss: 3226.7307 - val_readiness_mae: 55.8448 - val_recovery_loss: 2999.9875 - val_recovery_mae: 47.4889 - val_rhr_loss: 5537.1851 - val_rhr_mae: 74.1158 - val_sleep_loss: 5246.1519 - val_sleep_mae: 70.6447
# Epoch 5/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 5422.9878 - hrv_mae: 72.7476 - loss: 22654.2598 - readiness_loss: 3215.2434 - readiness_mae: 55.0385 - recovery_loss: 3059.6663 - recovery_mae: 47.2218 - rhr_loss: 5883.0254 - rhr_mae: 76.1245 - sleep_loss: 5073.3379 - sleep_mae: 68.8852 - val_hrv_loss: 5120.8901 - val_hrv_mae: 71.1987 - val_loss: 20910.5508 - val_readiness_loss: 2909.5134 - val_readiness_mae: 52.9055 - val_recovery_loss: 2784.2571 - val_recovery_mae: 45.9175 - val_rhr_loss: 5098.1611 - val_rhr_mae: 71.0984 - val_sleep_loss: 4832.3643 - val_sleep_mae: 67.8449
# Epoch 6/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 4996.2456 - hrv_mae: 69.7983 - loss: 20781.0352 - readiness_loss: 2895.1177 - readiness_mae: 52.0635 - recovery_loss: 2873.3965 - recovery_mae: 46.1439 - rhr_loss: 5410.0771 - rhr_mae: 72.9511 - sleep_loss: 4606.1987 - sleep_mae: 65.5710 - val_hrv_loss: 4713.6323 - val_hrv_mae: 68.2676 - val_loss: 19216.1621 - val_readiness_loss: 2619.6257 - val_readiness_mae: 50.0674 - val_recovery_loss: 2594.2646 - val_recovery_mae: 44.5130 - val_rhr_loss: 4687.2339 - val_rhr_mae: 68.1533 - val_sleep_loss: 4447.4043 - val_sleep_mae: 65.1239
# Epoch 7/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 4602.8027 - hrv_mae: 66.9171 - loss: 19121.6191 - readiness_loss: 2605.4038 - readiness_mae: 49.1641 - recovery_loss: 2654.2668 - recovery_mae: 44.4825 - rhr_loss: 4976.2915 - rhr_mae: 69.8904 - sleep_loss: 4282.8550 - sleep_mae: 63.0958 - val_hrv_loss: 4333.6743 - val_hrv_mae: 65.4141 - val_loss: 17649.5859 - val_readiness_loss: 2354.5366 - val_readiness_mae: 47.3221 - val_recovery_loss: 2425.1543 - val_recovery_mae: 43.2548 - val_rhr_loss: 4303.8579 - val_rhr_mae: 65.2862 - val_sleep_loss: 4089.3040 - val_sleep_mae: 62.4780
# Epoch 8/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - hrv_loss: 4231.6157 - hrv_mae: 64.1169 - loss: 17536.0215 - readiness_loss: 2340.1455 - readiness_mae: 46.4122 - recovery_loss: 2526.1833 - recovery_mae: 43.7525 - rhr_loss: 4571.4141 - rhr_mae: 66.9550 - sleep_loss: 3866.6624 - sleep_mae: 59.9401 - val_hrv_loss: 3977.9390 - val_hrv_mae: 62.6243 - val_loss: 16198.0498 - val_readiness_loss: 2111.8105 - val_readiness_mae: 44.6615 - val_recovery_loss: 2276.0920 - val_recovery_mae: 42.1112 - val_rhr_loss: 3944.3882 - val_rhr_mae: 62.4789 - val_sleep_loss: 3755.2332 - val_sleep_mae: 59.8954
# Epoch 9/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 3903.3555 - hrv_mae: 61.5269 - loss: 16235.9297 - readiness_loss: 2120.0266 - readiness_mae: 43.9922 - recovery_loss: 2318.1860 - recovery_mae: 41.9922 - rhr_loss: 4240.8423 - rhr_mae: 64.3834 - sleep_loss: 3653.5193 - sleep_mae: 58.4826 - val_hrv_loss: 3646.7783 - val_hrv_mae: 59.9101 - val_loss: 14861.6631 - val_readiness_loss: 1891.2319 - val_readiness_mae: 42.1077 - val_recovery_loss: 2145.8657 - val_recovery_mae: 41.0801 - val_rhr_loss: 3610.0076 - val_rhr_mae: 59.7494 - val_sleep_loss: 3445.1582 - val_sleep_mae: 57.3853
# Epoch 10/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - hrv_loss: 3581.0796 - hrv_mae: 58.7185 - loss: 14909.9414 - readiness_loss: 1903.1040 - readiness_mae: 41.4238 - recovery_loss: 2246.5671 - recovery_mae: 41.6075 - rhr_loss: 3873.1165 - rhr_mae: 61.4610 - sleep_loss: 3306.0757 - sleep_mae: 55.5322 - val_hrv_loss: 3337.2644 - val_hrv_mae: 57.2565 - val_loss: 13624.3809 - val_readiness_loss: 1689.8501 - val_readiness_mae: 39.6303 - val_recovery_loss: 2031.1790 - val_recovery_mae: 40.1424 - val_rhr_loss: 3296.3896 - val_rhr_mae: 57.0712 - val_sleep_loss: 3156.6475 - val_sleep_mae: 54.9374
# Epoch 11/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 3296.4373 - hrv_mae: 56.2517 - loss: 13802.2715 - readiness_loss: 1734.5076 - readiness_mae: 39.2358 - recovery_loss: 2189.3689 - recovery_mae: 41.4678 - rhr_loss: 3570.1763 - rhr_mae: 58.9303 - sleep_loss: 3011.7822 - sleep_mae: 52.8979 - val_hrv_loss: 3047.8584 - val_hrv_mae: 54.6584 - val_loss: 12479.8750 - val_readiness_loss: 1506.4352 - val_readiness_mae: 37.2300 - val_recovery_loss: 1931.0061 - val_recovery_mae: 39.3098 - val_rhr_loss: 3002.8669 - val_rhr_mae: 54.4457 - val_sleep_loss: 2887.8269 - val_sleep_mae: 52.5440
# Epoch 12/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 2986.6863 - hrv_mae: 53.4802 - loss: 12544.4434 - readiness_loss: 1518.6384 - readiness_mae: 36.6312 - recovery_loss: 1987.4111 - recovery_mae: 39.4841 - rhr_loss: 3271.8408 - rhr_mae: 56.3165 - sleep_loss: 2779.8669 - sleep_mae: 50.8307 - val_hrv_loss: 2777.9094 - val_hrv_mae: 52.1177 - val_loss: 11424.4082 - val_readiness_loss: 1339.8521 - val_readiness_mae: 34.9137 - val_recovery_loss: 1843.0420 - val_recovery_mae: 38.5431 - val_rhr_loss: 2729.5632 - val_rhr_mae: 51.8820 - val_sleep_loss: 2639.0071 - val_sleep_mae: 50.2169
# Epoch 13/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 2718.0371 - hrv_mae: 50.8754 - loss: 11523.9150 - readiness_loss: 1358.0262 - readiness_mae: 34.2688 - recovery_loss: 1922.0992 - recovery_mae: 39.0808 - rhr_loss: 3015.4272 - rhr_mae: 54.0109 - sleep_loss: 2510.3237 - sleep_mae: 48.2564 - val_hrv_loss: 2527.2046 - val_hrv_mae: 49.6412 - val_loss: 10454.7061 - val_readiness_loss: 1189.5223 - val_readiness_mae: 32.6803 - val_recovery_loss: 1768.0680 - val_recovery_mae: 37.8703 - val_rhr_loss: 2474.8335 - val_rhr_mae: 49.3732 - val_sleep_loss: 2408.4045 - val_sleep_mae: 47.9486
# Epoch 14/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 2454.7424 - hrv_mae: 48.1229 - loss: 10519.4834 - readiness_loss: 1200.3680 - readiness_mae: 31.7861 - recovery_loss: 1869.7947 - recovery_mae: 38.4586 - rhr_loss: 2712.0808 - rhr_mae: 51.0912 - sleep_loss: 2282.4980 - sleep_mae: 45.9194 - val_hrv_loss: 2293.7327 - val_hrv_mae: 47.2176 - val_loss: 9561.9756 - val_readiness_loss: 1053.7191 - val_readiness_mae: 30.5195 - val_recovery_loss: 1703.4117 - val_recovery_mae: 37.2710 - val_rhr_loss: 2238.0444 - val_rhr_mae: 46.9213 - val_sleep_loss: 2194.4014 - val_sleep_mae: 45.7318
# Epoch 15/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 2252.6826 - hrv_mae: 46.0340 - loss: 9710.4688 - readiness_loss: 1081.6864 - readiness_mae: 30.0808 - recovery_loss: 1772.4089 - recovery_mae: 37.7177 - rhr_loss: 2490.8760 - rhr_mae: 48.8368 - sleep_loss: 2112.8164 - sleep_mae: 44.2871 - val_hrv_loss: 2078.0591 - val_hrv_mae: 44.8619 - val_loss: 8748.4961 - val_readiness_loss: 932.7670 - val_readiness_mae: 28.4588 - val_recovery_loss: 1650.5813 - val_recovery_mae: 36.7508 - val_rhr_loss: 2018.5825 - val_rhr_mae: 44.5288 - val_sleep_loss: 1997.1903 - val_sleep_mae: 43.5773
# Epoch 16/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 2036.9189 - hrv_mae: 43.6371 - loss: 8902.7500 - readiness_loss: 954.8606 - readiness_mae: 27.9964 - recovery_loss: 1713.6404 - recovery_mae: 37.2144 - rhr_loss: 2282.3503 - rhr_mae: 46.6521 - sleep_loss: 1914.9801 - sleep_mae: 42.0791 - val_hrv_loss: 1877.7640 - val_hrv_mae: 42.5620 - val_loss: 8000.0562 - val_readiness_loss: 823.8256 - val_readiness_mae: 26.4669 - val_recovery_loss: 1604.3308 - val_recovery_mae: 36.2748 - val_rhr_loss: 1814.6759 - val_rhr_mae: 42.1849 - val_sleep_loss: 1815.3226 - val_sleep_mae: 41.4788
# Epoch 17/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 1878.8417 - hrv_mae: 41.7620 - loss: 8300.8311 - readiness_loss: 878.2566 - readiness_mae: 26.4764 - recovery_loss: 1704.6245 - recovery_mae: 37.2081 - rhr_loss: 2060.2815 - rhr_mae: 44.1073 - sleep_loss: 1778.8274 - sleep_mae: 40.4580 - val_hrv_loss: 1692.9672 - val_hrv_mae: 40.3360 - val_loss: 7319.1392 - val_readiness_loss: 727.1849 - val_readiness_mae: 24.5759 - val_recovery_loss: 1566.4055 - val_recovery_mae: 35.8642 - val_rhr_loss: 1626.9280 - val_rhr_mae: 39.9055 - val_sleep_loss: 1648.1991 - val_sleep_mae: 39.4391
# Epoch 18/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 1698.9386 - hrv_mae: 39.5750 - loss: 7631.9980 - readiness_loss: 789.2694 - readiness_mae: 24.9516 - recovery_loss: 1661.6638 - recovery_mae: 36.7081 - rhr_loss: 1880.4929 - rhr_mae: 42.0554 - sleep_loss: 1601.6335 - sleep_mae: 38.1795 - val_hrv_loss: 1522.9520 - val_hrv_mae: 38.1792 - val_loss: 6700.1445 - val_readiness_loss: 641.7388 - val_readiness_mae: 22.8079 - val_recovery_loss: 1535.1653 - val_recovery_mae: 35.5049 - val_rhr_loss: 1453.4749 - val_rhr_mae: 37.6778 - val_sleep_loss: 1495.6261 - val_sleep_mae: 37.4665
# Epoch 19/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 1526.3237 - hrv_mae: 37.4264 - loss: 6969.3311 - readiness_loss: 684.3351 - readiness_mae: 23.0226 - recovery_loss: 1578.6885 - recovery_mae: 35.6114 - rhr_loss: 1698.1376 - rhr_mae: 39.8195 - sleep_loss: 1481.8464 - sleep_mae: 36.6433 - val_hrv_loss: 1366.3525 - val_hrv_mae: 36.0846 - val_loss: 6136.7178 - val_readiness_loss: 566.2188 - val_readiness_mae: 21.1942 - val_recovery_loss: 1509.8137 - val_recovery_mae: 35.1885 - val_rhr_loss: 1294.1370 - val_rhr_mae: 35.5090 - val_sleep_loss: 1354.8542 - val_sleep_mae: 35.5349
# Epoch 20/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - hrv_loss: 1385.3990 - hrv_mae: 35.3749 - loss: 6461.0381 - readiness_loss: 631.6361 - readiness_mae: 21.9660 - recovery_loss: 1615.9313 - recovery_mae: 36.2842 - rhr_loss: 1509.1483 - rhr_mae: 37.2137 - sleep_loss: 1318.9243 - sleep_mae: 34.5007 - val_hrv_loss: 1223.2417 - val_hrv_mae: 34.0578 - val_loss: 5630.7847 - val_readiness_loss: 500.9215 - val_readiness_mae: 19.7594 - val_recovery_loss: 1489.9055 - val_recovery_mae: 34.9138 - val_rhr_loss: 1148.3684 - val_rhr_mae: 33.4022 - val_sleep_loss: 1228.3308 - val_sleep_mae: 33.6894

# %%
encoder = Model(
    inputs=fitbit_model.input,
    outputs=fitbit_model.get_layer("encoder_lstm_2").output
)

encoder.save("fitbit_encoder.keras")

# %% [markdown]
# ## Fine Tuning

# %%
df = pd.read_csv(
    "/kaggle/input/smartwatch-clean-dataset/smartwatch_clean.csv"
)

# %%
df.head()
# Out:
#    heart_rate  blood_oxygen_level    step_count  sleep_duration  \
# 0   58.939776           98.809650   5450.390578        7.167236
# 1   74.883189           98.532195    727.601610        6.538239
# 2  247.803052           97.052954   2826.521994        6.515466
# 3   40.000000           96.894213  13797.338044        7.367790
# 4   61.950165           98.583797  15679.067648        6.515466
#
#   activity_level stress_level
# 0  Highly Active            1
# 1  Highly Active            5
# 2  Highly Active            5
# 3         Active            3
# 4  Highly Active            6

# %%
from sklearn.preprocessing import LabelEncoder

dataolahencoding = df.copy() # Membuat salinan dataset untuk mencegah modifikasi dataset asli

# Label encoding 
encoder = LabelEncoder()
dataolahencoding['heart_rate_encod'] = encoder.fit_transform(dataolahencoding['heart_rate'])
dataolahencoding['blood_oxygen_level_encod'] = encoder.fit_transform(dataolahencoding['blood_oxygen_level'])
dataolahencoding['step_count_encod'] = encoder.fit_transform(dataolahencoding['step_count'])
dataolahencoding['sleep_duration_encod'] = encoder.fit_transform(dataolahencoding['sleep_duration'])
dataolahencoding['activity_level_encod'] = encoder.fit_transform(dataolahencoding['activity_level'])
dataolahencoding['stress_level_encod'] = encoder.fit_transform(dataolahencoding['stress_level'])

# %%
dataolahencoding = dataolahencoding.drop(['heart_rate', 'blood_oxygen_level', 'step_count', 'sleep_duration', 'activity_level','stress_level'], axis=1)
dataolahencoding.head(100)
# Out:
#     heart_rate_encod  blood_oxygen_level_encod  step_count_encod  \
# 0               1240                      6185              5207
# 1               4508                      5703               947
# 2               9299                      3043              3220
# 3                  0                      2772              8356
# 4               1711                      5789              8692
# ..               ...                       ...               ...
# 95                 0                       707              7660
# 96              7987                      4604               116
# 97                96                      8012              3120
# 98              9154                      7804              4945
# 99               580                       749              9039
#
#     sleep_duration_encod  activity_level_encod  stress_level_encod
# 0                   6330                     1                   0
# 1                   4802                     1                   5
# 2                   4743                     1                   5
# 3                   6747                     0                   3
# 4                   4743                     1                   6
# ..                   ...                   ...                 ...
# 95                  8342                     0                   4
# 96                  5353                     0                   6
# 97                  5408                     0                   6
# 98                  4903                     2                   1
# 99                  6726                     1                   2
#
# [100 rows x 6 columns]

# %%
dataolahencoding["sleep_score"] = np.clip((dataolahencoding["sleep_duration_encod"] / 8) * 100, 0, 100)
dataolahencoding["rhr_score"] = np.clip(100 - (dataolahencoding["heart_rate_encod"] - 60) * 2, 0, 100)
dataolahencoding["hrv_score"] = np.clip(100 - abs(dataolahencoding["heart_rate_encod"] - dataolahencoding["heart_rate_encod"].mean()), 0, 100)
dataolahencoding["recovery_score"] = np.clip(100 - dataolahencoding["stress_level_encod"] * 10, 0, 100)

dataolahencoding["readiness_score"] = (
    0.30 * dataolahencoding["sleep_score"] +
    0.25 * dataolahencoding["recovery_score"] +
    0.20 * dataolahencoding["hrv_score"] +
    0.15 * dataolahencoding["rhr_score"]
)

# %%
FEATURES = ["heart_rate_encod", "blood_oxygen_level_encod", "step_count_encod", "stress_level_encod"]
TARGETS = ["sleep_score", "hrv_score", "rhr_score", "recovery_score", "readiness_score"]

SEQ_LEN = 6
X, y = [], []

for i in range(len(dataolahencoding) - SEQ_LEN):
    X.append(dataolahencoding[FEATURES].iloc[i:i+SEQ_LEN].values)
    y.append(dataolahencoding[TARGETS].iloc[i+SEQ_LEN].values)

X = np.array(X)
y = np.array(y)

# %%
from tensorflow.keras.models import load_model

encoder = load_model("fitbit_encoder.keras")

for layer in encoder.layers:
    layer.trainable = False   # freeze encoder

# %%
input_layer = Input(shape=(SEQ_LEN, len(FEATURES)))
shared = encoder(input_layer)

shared = Dense(32, activation="relu")(shared)

outputs = [
    Dense(1, name="sleep")(shared),
    Dense(1, name="hrv")(shared),
    Dense(1, name="rhr")(shared),
    Dense(1, name="recovery")(shared),
    Dense(1, name="readiness")(shared)
]

final_model = Model(input_layer, outputs)

final_model.compile(
    optimizer=Adam(0.0005),
    loss="mse",
    metrics={
        "sleep": "mae",
        "hrv": "mae",
        "rhr": "mae",
        "recovery": "mae",
        "readiness": "mae"
    }
)


final_model.fit(
    X,
    [y[:,0], y[:,1], y[:,2], y[:,3], y[:,4]],
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - hrv_loss: 199.6698 - hrv_mae: 3.5027 - loss: 15547.6631 - readiness_loss: 1728.6748 - readiness_mae: 40.6959 - recovery_loss: 3669.6023 - recovery_mae: 53.1427 - rhr_loss: 150.2372 - rhr_mae: 2.1563 - sleep_loss: 9799.4639 - sleep_mae: 98.9537 - val_hrv_loss: 161.0831 - val_hrv_mae: 4.3760 - val_loss: 11642.8975 - val_readiness_loss: 814.8217 - val_readiness_mae: 27.4255 - val_recovery_loss: 2413.1995 - val_recovery_mae: 40.8170 - val_rhr_loss: 190.5660 - val_rhr_mae: 3.5883 - val_sleep_loss: 8058.0444 - val_sleep_mae: 89.7666
# Epoch 2/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - hrv_loss: 187.0610 - hrv_mae: 5.3566 - loss: 10091.1904 - readiness_loss: 553.2809 - readiness_mae: 21.4434 - recovery_loss: 2078.1401 - recovery_mae: 37.5977 - rhr_loss: 142.7758 - rhr_mae: 3.2440 - sleep_loss: 7129.9150 - sleep_mae: 84.2583 - val_hrv_loss: 161.1420 - val_hrv_mae: 5.4356 - val_loss: 5716.1377 - val_readiness_loss: 70.6556 - val_readiness_mae: 7.0144 - val_recovery_loss: 1036.4803 - val_recovery_mae: 26.8979 - val_rhr_loss: 190.3135 - val_rhr_mae: 4.0661 - val_sleep_loss: 4253.9653 - val_sleep_mae: 65.2224
# Epoch 3/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 181.0758 - hrv_mae: 5.5058 - loss: 4759.5288 - readiness_loss: 67.7484 - readiness_mae: 6.8143 - recovery_loss: 939.1351 - recovery_mae: 26.0305 - rhr_loss: 134.3632 - rhr_mae: 3.0411 - sleep_loss: 3437.1978 - sleep_mae: 58.3070 - val_hrv_loss: 160.8724 - val_hrv_mae: 5.1672 - val_loss: 2772.6189 - val_readiness_loss: 84.3445 - val_readiness_mae: 7.5690 - val_recovery_loss: 841.1362 - val_recovery_mae: 25.3131 - val_rhr_loss: 190.3945 - val_rhr_mae: 3.7956 - val_sleep_loss: 1493.4460 - val_sleep_mae: 38.6451
# Epoch 4/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 148.8173 - hrv_mae: 4.7040 - loss: 2329.0374 - readiness_loss: 77.9429 - readiness_mae: 7.3071 - recovery_loss: 828.0289 - recovery_mae: 24.9352 - rhr_loss: 163.0576 - rhr_mae: 3.4099 - sleep_loss: 1111.1899 - sleep_mae: 32.9727 - val_hrv_loss: 161.4626 - val_hrv_mae: 5.6397 - val_loss: 1601.9824 - val_readiness_loss: 68.2712 - val_readiness_mae: 6.9431 - val_recovery_loss: 859.0310 - val_recovery_mae: 25.3607 - val_rhr_loss: 190.5364 - val_rhr_mae: 3.6172 - val_sleep_loss: 320.3539 - val_sleep_mae: 17.8984
# Epoch 5/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 151.7743 - hrv_mae: 4.8658 - loss: 1425.0917 - readiness_loss: 64.7792 - readiness_mae: 6.7767 - recovery_loss: 847.5707 - recovery_mae: 25.2025 - rhr_loss: 145.6202 - rhr_mae: 3.1297 - sleep_loss: 215.3454 - sleep_mae: 14.3557 - val_hrv_loss: 162.0057 - val_hrv_mae: 5.8956 - val_loss: 1298.5442 - val_readiness_loss: 63.3733 - val_readiness_mae: 6.7279 - val_recovery_loss: 843.2049 - val_recovery_mae: 25.3209 - val_rhr_loss: 190.3692 - val_rhr_mae: 3.8416 - val_sleep_loss: 37.0956 - val_sleep_mae: 6.0906
# Epoch 6/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 186.8920 - hrv_mae: 5.7197 - loss: 1260.3937 - readiness_loss: 62.9915 - readiness_mae: 6.6547 - recovery_loss: 825.5320 - recovery_mae: 24.9892 - rhr_loss: 156.4975 - rhr_mae: 3.3355 - sleep_loss: 28.4820 - sleep_mae: 4.6841 - val_hrv_loss: 160.7766 - val_hrv_mae: 4.8492 - val_loss: 1256.6627 - val_readiness_loss: 62.7250 - val_readiness_mae: 6.7087 - val_recovery_loss: 837.8395 - val_recovery_mae: 25.2963 - val_rhr_loss: 190.5628 - val_rhr_mae: 3.5913 - val_sleep_loss: 2.3145 - val_sleep_mae: 1.5214
# Epoch 7/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 178.7929 - hrv_mae: 5.1799 - loss: 1233.6089 - readiness_loss: 61.7747 - readiness_mae: 6.5970 - recovery_loss: 825.2674 - recovery_mae: 24.9216 - rhr_loss: 163.6886 - rhr_mae: 3.3446 - sleep_loss: 4.0859 - sleep_mae: 1.1101 - val_hrv_loss: 161.5363 - val_hrv_mae: 5.6792 - val_loss: 1254.2657 - val_readiness_loss: 62.6581 - val_readiness_mae: 6.7141 - val_recovery_loss: 836.7008 - val_recovery_mae: 25.2870 - val_rhr_loss: 190.6334 - val_rhr_mae: 3.5282 - val_sleep_loss: 0.1323 - val_sleep_mae: 0.3638
# Epoch 8/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - hrv_loss: 179.8238 - hrv_mae: 5.5868 - loss: 1214.1562 - readiness_loss: 62.0513 - readiness_mae: 6.6005 - recovery_loss: 818.5267 - recovery_mae: 24.8427 - rhr_loss: 150.0779 - rhr_mae: 3.0590 - sleep_loss: 3.6789 - sleep_mae: 0.2995 - val_hrv_loss: 160.7884 - val_hrv_mae: 4.7779 - val_loss: 1253.4528 - val_readiness_loss: 62.6666 - val_readiness_mae: 6.7133 - val_recovery_loss: 836.9208 - val_recovery_mae: 25.2892 - val_rhr_loss: 190.6101 - val_rhr_mae: 3.5482 - val_sleep_loss: 0.0043 - val_sleep_mae: 0.0652
# Epoch 9/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 188.8372 - hrv_mae: 5.4154 - loss: 1217.1108 - readiness_loss: 61.6250 - readiness_mae: 6.5640 - recovery_loss: 813.8806 - recovery_mae: 24.7075 - rhr_loss: 150.5687 - rhr_mae: 3.1357 - sleep_loss: 2.2022 - sleep_mae: 0.1000 - val_hrv_loss: 160.7990 - val_hrv_mae: 5.0234 - val_loss: 1252.8232 - val_readiness_loss: 62.6196 - val_readiness_mae: 6.7214 - val_recovery_loss: 836.2635 - val_recovery_mae: 25.2817 - val_rhr_loss: 190.5971 - val_rhr_mae: 3.5598 - val_sleep_loss: 0.0189 - val_sleep_mae: 0.1373
# Epoch 10/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 176.1735 - hrv_mae: 5.2233 - loss: 1261.1392 - readiness_loss: 63.8083 - readiness_mae: 6.7236 - recovery_loss: 836.8030 - recovery_mae: 25.2228 - rhr_loss: 181.1665 - rhr_mae: 3.6185 - sleep_loss: 3.1857 - sleep_mae: 0.1246 - val_hrv_loss: 160.8984 - val_hrv_mae: 5.2030 - val_loss: 1252.8517 - val_readiness_loss: 62.6192 - val_readiness_mae: 6.7218 - val_recovery_loss: 836.2224 - val_recovery_mae: 25.2811 - val_rhr_loss: 190.5341 - val_rhr_mae: 3.6195 - val_sleep_loss: 0.0268 - val_sleep_mae: 0.1637
# Epoch 11/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 175.8280 - hrv_mae: 5.1790 - loss: 1227.0692 - readiness_loss: 63.6553 - readiness_mae: 6.7188 - recovery_loss: 833.0284 - recovery_mae: 25.1367 - rhr_loss: 148.8229 - rhr_mae: 3.1021 - sleep_loss: 5.7342 - sleep_mae: 0.1698 - val_hrv_loss: 160.7755 - val_hrv_mae: 4.8994 - val_loss: 1252.4675 - val_readiness_loss: 62.6193 - val_readiness_mae: 6.7234 - val_recovery_loss: 836.1561 - val_recovery_mae: 25.2800 - val_rhr_loss: 190.3905 - val_rhr_mae: 3.8022 - val_sleep_loss: 0.0261 - val_sleep_mae: 0.1615
# Epoch 12/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 172.7069 - hrv_mae: 5.1015 - loss: 1217.0879 - readiness_loss: 61.5795 - readiness_mae: 6.5998 - recovery_loss: 823.1002 - recovery_mae: 24.9142 - rhr_loss: 156.4838 - rhr_mae: 3.2852 - sleep_loss: 3.2173 - sleep_mae: 0.1476 - val_hrv_loss: 160.8086 - val_hrv_mae: 5.0493 - val_loss: 1252.8547 - val_readiness_loss: 62.6453 - val_readiness_mae: 6.7294 - val_recovery_loss: 835.9464 - val_recovery_mae: 25.2752 - val_rhr_loss: 190.8236 - val_rhr_mae: 3.3869 - val_sleep_loss: 0.0691 - val_sleep_mae: 0.2628
# Epoch 13/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 177.5815 - hrv_mae: 5.2652 - loss: 1231.3802 - readiness_loss: 62.2061 - readiness_mae: 6.6830 - recovery_loss: 838.8767 - recovery_mae: 25.2703 - rhr_loss: 149.0893 - rhr_mae: 2.9550 - sleep_loss: 3.6253 - sleep_mae: 0.1913 - val_hrv_loss: 160.8177 - val_hrv_mae: 4.6945 - val_loss: 1253.2344 - val_readiness_loss: 62.6616 - val_readiness_mae: 6.7138 - val_recovery_loss: 837.0227 - val_recovery_mae: 25.2901 - val_rhr_loss: 190.3138 - val_rhr_mae: 4.0530 - val_sleep_loss: 6.5874e-05 - val_sleep_mae: 0.0078
# Epoch 14/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 181.5773 - hrv_mae: 5.2299 - loss: 1250.6444 - readiness_loss: 63.7298 - readiness_mae: 6.7136 - recovery_loss: 842.5939 - recovery_mae: 25.2549 - rhr_loss: 159.9945 - rhr_mae: 3.4701 - sleep_loss: 2.7476 - sleep_mae: 0.1436 - val_hrv_loss: 160.8018 - val_hrv_mae: 5.0313 - val_loss: 1252.9904 - val_readiness_loss: 62.6282 - val_readiness_mae: 6.7184 - val_recovery_loss: 836.6342 - val_recovery_mae: 25.2863 - val_rhr_loss: 190.4176 - val_rhr_mae: 3.7592 - val_sleep_loss: 0.0097 - val_sleep_mae: 0.0986
# Epoch 15/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - hrv_loss: 186.7472 - hrv_mae: 5.3278 - loss: 1233.2632 - readiness_loss: 63.7330 - readiness_mae: 6.7405 - recovery_loss: 839.0864 - recovery_mae: 25.2488 - rhr_loss: 138.9291 - rhr_mae: 2.9622 - sleep_loss: 4.7680 - sleep_mae: 0.2018 - val_hrv_loss: 160.9028 - val_hrv_mae: 5.2087 - val_loss: 1254.1656 - val_readiness_loss: 62.7781 - val_readiness_mae: 6.7056 - val_recovery_loss: 837.3409 - val_recovery_mae: 25.2927 - val_rhr_loss: 190.6251 - val_rhr_mae: 3.5352 - val_sleep_loss: 0.0046 - val_sleep_mae: 0.0681
# Epoch 16/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - hrv_loss: 178.8672 - hrv_mae: 5.2652 - loss: 1242.6483 - readiness_loss: 63.6606 - readiness_mae: 6.6947 - recovery_loss: 819.8306 - recovery_mae: 24.8715 - rhr_loss: 176.3848 - rhr_mae: 3.5556 - sleep_loss: 3.9093 - sleep_mae: 0.1772 - val_hrv_loss: 160.7862 - val_hrv_mae: 4.9786 - val_loss: 1255.1533 - val_readiness_loss: 62.8774 - val_readiness_mae: 6.7010 - val_recovery_loss: 838.4850 - val_recovery_mae: 25.3003 - val_rhr_loss: 190.5289 - val_rhr_mae: 3.6248 - val_sleep_loss: 0.0281 - val_sleep_mae: 0.1677
# Epoch 17/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - hrv_loss: 167.9990 - hrv_mae: 4.9709 - loss: 1233.7504 - readiness_loss: 62.8296 - readiness_mae: 6.6436 - recovery_loss: 821.5771 - recovery_mae: 24.9494 - rhr_loss: 174.5736 - rhr_mae: 3.5961 - sleep_loss: 6.7692 - sleep_mae: 0.2278 - val_hrv_loss: 160.7960 - val_hrv_mae: 5.0144 - val_loss: 1253.2179 - val_readiness_loss: 62.6386 - val_readiness_mae: 6.7285 - val_recovery_loss: 836.1285 - val_recovery_mae: 25.2795 - val_rhr_loss: 191.0459 - val_rhr_mae: 3.2522 - val_sleep_loss: 0.0597 - val_sleep_mae: 0.2444
# Epoch 18/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 167.0152 - hrv_mae: 5.0270 - loss: 1248.0227 - readiness_loss: 62.2882 - readiness_mae: 6.6481 - recovery_loss: 838.0877 - recovery_mae: 25.1525 - rhr_loss: 178.3039 - rhr_mae: 3.4563 - sleep_loss: 2.3280 - sleep_mae: 0.1301 - val_hrv_loss: 161.0727 - val_hrv_mae: 5.3807 - val_loss: 1254.1454 - val_readiness_loss: 62.6230 - val_readiness_mae: 6.7198 - val_recovery_loss: 836.8132 - val_recovery_mae: 25.2882 - val_rhr_loss: 191.0462 - val_rhr_mae: 3.2521 - val_sleep_loss: 0.0184 - val_sleep_mae: 0.1358
# Epoch 19/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - hrv_loss: 146.9811 - hrv_mae: 4.7271 - loss: 1223.2700 - readiness_loss: 62.4976 - readiness_mae: 6.6551 - recovery_loss: 837.5456 - recovery_mae: 25.1469 - rhr_loss: 174.6837 - rhr_mae: 3.4046 - sleep_loss: 1.5608 - sleep_mae: 0.1323 - val_hrv_loss: 160.9075 - val_hrv_mae: 5.2147 - val_loss: 1252.9955 - val_readiness_loss: 62.6200 - val_readiness_mae: 6.7211 - val_recovery_loss: 836.1449 - val_recovery_mae: 25.2798 - val_rhr_loss: 190.7352 - val_rhr_mae: 3.4486 - val_sleep_loss: 0.0210 - val_sleep_mae: 0.1450
# Epoch 20/20
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - hrv_loss: 169.6935 - hrv_mae: 5.1855 - loss: 1224.7043 - readiness_loss: 62.6585 - readiness_mae: 6.6504 - recovery_loss: 829.3184 - recovery_mae: 25.0656 - rhr_loss: 159.2121 - rhr_mae: 3.2374 - sleep_loss: 3.8251 - sleep_mae: 0.1624 - val_hrv_loss: 160.7820 - val_hrv_mae: 4.9577 - val_loss: 1253.0813 - val_readiness_loss: 62.6189 - val_readiness_mae: 6.7228 - val_recovery_loss: 836.0101 - val_recovery_mae: 25.2770 - val_rhr_loss: 191.1179 - val_rhr_mae: 3.2132 - val_sleep_loss: 1.3003e-04 - val_sleep_mae: 0.0112
